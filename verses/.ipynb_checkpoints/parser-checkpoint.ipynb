# %%
import requests
import json
from bs4 import BeautifulSoup
from IPython.core.display import HTML
import pprint

# %%
LIB_POETRY = 'http://lib.ru/POEZIQ/'

# %%
req = requests.get(LIB_POETRY)
soup = BeautifulSoup(req.text)
print(soup)
# Out:
# <html><head><title>Lib.Ru: Поэзия</title></head>
# <body>
# ...

# %%
HTML(req.text)
# Out:
# <html><head><title>Lib.Ru: Поэзия</title></head>
# <body>
# ...
